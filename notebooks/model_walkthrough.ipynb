# %% [markdown]
# # RAFM-inspired Cash-Flow Model Walkthrough
#
# This notebook is intended to walk through the simplified savings-insurance cash-flow model.
#
# Planned sections:
#
# 1. Load synthetic policy data
# 2. Load model assumptions
# 3. Run base-case projection
# 4. Run scenario analysis
# 5. Interpret valuation and profitability results
